# %%
import pandas as pd
import numpy as np

# %%
file = pd.read_csv("dc_airbnb.csv")
file.head()
# Out:
#   host_response_rate host_acceptance_rate  host_listings_count  accommodates  \
# 0                92%                  91%                   26             4
# 1                90%                 100%                    1             6
# 2                90%                 100%                    2             1
# 3               100%                  NaN                    1             2
# 4                92%                  67%                    1             4
#
#          room_type  bedrooms  bathrooms  beds    price cleaning_fee  \
# 0  Entire home/apt       1.0        1.0   2.0  $160.00      $115.00
# 1  Entire home/apt       3.0        3.0   3.0  $350.00      $100.00
# 2     Private room       1.0        2.0   1.0   $50.00          NaN
# 3     Private room       1.0        1.0   1.0   $95.00          NaN
# 4  Entire home/apt       1.0        1.0   1.0   $50.00       $15.00
#
#   security_deposit  minimum_nights  maximum_nights  number_of_reviews  \
# 0          $100.00               1            1125                  0
# 1              NaN               2              30                 65
# 2              NaN               2            1125                  1
# 3              NaN               1            1125                  0
# 4          $450.00               7            1125                  0
#
#     latitude  longitude           city zipcode state
# 0  38.890046 -77.002808     Washington   20003    DC
# 1  38.880413 -76.990485     Washington   20003    DC
# 2  38.955291 -76.986006    Hyattsville   20782    MD
# 3  38.872134 -77.019639     Washington   20024    DC
# 4  38.996382 -77.041541  Silver Spring   20910    MD

# %%
file["price"] = file["price"].str.replace("$","").str.replace(",","").astype(float)

# %%
file["price"].head()
# Out:
# 0    160.0
# 1    350.0
# 2     50.0
# 3     95.0
# 4     50.0
# Name: price, dtype: float64

# %%
np.random.seed(123)
shuffle = np.random.permutation(file.index)
file = file.loc[shuffle]

# %% [markdown]
# ### algorithm doesn't work if null values are present in column

# %%
#data cleaning
file.isnull().sum()
# Out:
# host_response_rate       434
# host_acceptance_rate     614
# host_listings_count        0
# accommodates               0
# room_type                  0
# bedrooms                  21
# bathrooms                 27
# beds                      11
# price                      0
# cleaning_fee            1388
# security_deposit        2297
# minimum_nights             0
# maximum_nights             0
# number_of_reviews          0
# latitude                   0
# longitude                  0
# city                       0
# zipcode                    9
# state                      0
# dtype: int64

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3723 entries, 1657 to 3582
# Data columns (total 19 columns):
# host_response_rate      3289 non-null object
# host_acceptance_rate    3109 non-null object
# host_listings_count     3723 non-null int64
# accommodates            3723 non-null int64
# room_type               3723 non-null object
# bedrooms                3702 non-null float64
# bathrooms               3696 non-null float64
# beds                    3712 non-null float64
# price                   3723 non-null float64
# cleaning_fee            2335 non-null object
# security_deposit        1426 non-null object
# minimum_nights          3723 non-null int64
# maximum_nights          3723 non-null int64
# number_of_reviews       3723 non-null int64
# latitude                3723 non-null float64
# longitude               3723 non-null float64
# city                    3723 non-null object
# zipcode                 3714 non-null object
# state                   3723 non-null object
# dtypes: float64(6), int64(5), object(8)
# memory usage: 581.7+ KB

# %% [markdown]
# ### Algorithm only works on numerical data. so dropping rows with data type "object" (qualitative)

# %%
obj = ["host_response_rate","host_acceptance_rate","room_type","city","zipcode","state","cleaning_fee","security_deposit"]
file.drop(obj, axis=1, inplace= True)
#file.info()

# %%
file.dropna(axis=0,inplace=True)
file.isnull().sum()
# Out:
# host_listings_count    0
# accommodates           0
# bedrooms               0
# bathrooms              0
# beds                   0
# price                  0
# minimum_nights         0
# maximum_nights         0
# number_of_reviews      0
# latitude               0
# longitude              0
# dtype: int64

# %%
file.drop(["longitude","latitude"], axis=1, inplace=True)
#file
# Out:
#       host_listings_count  accommodates  bedrooms  bathrooms  beds  price  \
# 1657                    1             4       1.0        1.0   2.0  125.0
# 820                     6             1       0.0        1.0   1.0   95.0
# 2405                    2             6       2.0        2.5   2.0  399.0
# 298                     2             2       0.0        1.0   1.0  130.0
# 3670                    1             2       1.0        1.0   1.0   90.0
# 822                     1             2       1.0        0.0   1.0   85.0
# 1820                    1             2       0.0        1.0   1.0   80.0
# 3096                    1             2       1.0        1.0   1.0   55.0
# 1566                    1             3       1.0        1.0   1.0   88.0
# 2142                    1             2       1.0        1.5   1.0  107.0
# 2371                    1             2       1.0        1.0   1.0   25.0
# 2504                    1             4       1.0        1.0   2.0   99.0
# 2176                    1             4       1.0        1.0   2.0  135.0
# 3665                    1             2       1.0        1.0   1.0  108.0
# 1708                    4             4       1.0        1.5   1.0  109.0
# 2147                    3             4       2.0        1.0   2.0  150.0
# 3513                    4             6       1.0        1.0   3.0  191.0
# 198                     1             4       1.0        1.0   2.0  120.0
# 682                     1             2       1.0        1.0   1.0   90.0
# 3693                    2             1       1.0        1.0   1.0  100.0
# 773                     1             4       2.0        1.0   3.0  125.0
# 2715                    4             3       0.0        1.0   1.0   95.0
# 730                     1             3       1.0        1.0   3.0   50.0
# 1064                    1             2       1.0        1.0   1.0  100.0
# 2750                    1             4       1.0        1.0   2.0  110.0
# 3255                    1             2       1.0        1.0   1.0   72.0
# 1609                    2             2       1.0        1.0   1.0   85.0
# 1224                    3            16       1.0        2.0   1.0  499.0
# 1255                    1             2       1.0        1.0   1.0  120.0
# 471                     1             4       2.0        1.0   2.0  150.0
# ...                   ...           ...       ...        ...   ...    ...
# 1847                    3             4       1.0        1.0   1.0   45.0
# 1092                    1             2       1.0        1.0   1.0  122.0
# 3280                    3             5       0.0        1.0   3.0   80.0
# 2656                    1             2       1.0        1.0   1.0   95.0
# 2468                    1             2       1.0        1.0   1.0  100.0
# 3325                    1             2       1.0        1.0   1.0   60.0
# 2894                    1             2       1.0        1.0   1.0   99.0
# 1363                    1             4       1.0        1.0   1.0  135.0
# 3481                    1             6       2.0        1.5   2.0  205.0
# 111                     1             2       0.0        1.0   1.0  115.0
# 2272                    1             2       0.0        1.0   1.0  100.0
# 942                    32             4       1.0        1.0   1.0  149.0
# 1568                    5             4       2.0        2.5   2.0  120.0
# 73                      1             2       1.0        1.0   1.0   90.0
# 47                      5             1       1.0        1.0   1.0   55.0
# 2686                    1             1       1.0        1.5   1.0   45.0
# 2161                    1             3       1.0        1.0   1.0  105.0
# 96                    480             5       2.0        2.0   2.0  299.0
# 1761                    1             3       1.0        1.0   1.0  300.0
# 3286                    1             1       1.0        1.0   1.0   85.0
# 1593                    2             2       1.0        1.5   1.0   85.0
# 1147                    1             2       1.0        1.0   1.0   84.0
# 3667                    2             3       1.0        1.0   2.0   90.0
# 3089                    1             4       1.0        1.0   3.0  100.0
# 1766                    8             5       2.0        2.0   4.0  150.0
# 1122                    1             3       1.0        1.0   3.0  176.0
# 1346                    2             2       1.0        1.0   1.0   95.0
# 3454                    1             5       1.0        1.0   3.0  160.0
# 3437                    1             3       2.0        2.0   2.0  159.0
# 3582                    1             3       1.0        1.0   2.0   99.0
#
#       minimum_nights  maximum_nights  number_of_reviews
# 1657               2            1125                  1
# 820                5            1125                  0
# 2405               2            1125                  1
# 298                2             180                 19
# 3670               1            1125                  1
# 822                3            1125                  1
# 1820               1            1125                  4
# 3096               1            1125                 34
# 1566               1            1125                  0
# 2142               1            1125                  4
# 2371               1            1125                  1
# 2504               2              19                 35
# 2176               2            1125                 14
# 3665               1              90                 46
# 1708               1            1825                 96
# 2147               3             120                  0
# 3513               1             180                198
# 198                3              20                  3
# 682                3            1125                  5
# 3693               1            1125                  0
# 773                1            1125                  1
# 2715               3            1125                 11
# 730                1            1125                  1
# 1064               1            1125                 10
# 2750               2            1125                 26
# 3255               2            1125                 23
# 1609               2            1125                  6
# 1224               1            1125                  0
# 1255               1            1125                  1
# 471                2              14                 43
# ...              ...             ...                ...
# 1847               2             365                  3
# 1092               2            1125                  3
# 3280               1            1125                 67
# 2656               2            1125                 16
# 2468               1            1125                  0
# 3325               1            1125                  2
# 2894               5            1125                  0
# 1363               1              12                 36
# 3481               2              30                  3
# 111                1            1125                  0
# 2272               2              14                  1
# 942                4             365                 19
# 1568               1            1125                 20
# 73                 2            1125                  6
# 47                 1            1125                  0
# 2686               2               4                  0
# 2161               1             365                  7
# 96                 3             365                 34
# 1761               1               3                  0
# 3286               1            1125                  3
# 1593               1              30                 49
# 1147               1            1125                  3
# 3667               1              24                167
# 3089               2            1125                  1
# 1766               4            1125                  0
# 1122               1            1125                 20
# 1346               1            1125                  4
# 3454               2              29                 33
# 3437               5            1125                  2
# 3582               1              29                 13
#
# [3671 rows x 9 columns]

# %% [markdown]
# ### Columns like minimum nights etc need to be standardized or normalized. This can be done by calculating the Z Score

# %%
normalized = (file - file.mean())/file.std()
normalized.head()
# Out:
#       host_listings_count  accommodates  bedrooms  bathrooms      beds  \
# 1657            -0.190090      0.401366 -0.249467  -0.439151  0.297345
# 820             -0.109668     -1.095499 -1.438810  -0.439151 -0.546858
# 2405            -0.174005      1.399275  0.939875   2.117072  0.297345
# 298             -0.174005     -0.596544 -1.438810  -0.439151 -0.546858
# 3670            -0.190090     -0.596544 -0.249467  -0.439151 -0.546858
#
#          price  minimum_nights  maximum_nights  number_of_reviews
# 1657 -0.173345       -0.065038       -0.016573          -0.482505
# 820  -0.391448        0.763971       -0.016573          -0.516709
# 2405  1.818657       -0.065038       -0.016573          -0.482505
# 298  -0.136995       -0.065038       -0.016599           0.133163
# 3670 -0.427798       -0.341375       -0.016573          -0.482505

# %% [markdown]
# ### However we need the price in its original form. As we have to predict the price. So we update this column from our previous dataframe

# %%
normalized["price"] = file["price"]
normalized.head()
# Out:
#       host_listings_count  accommodates  bedrooms  bathrooms      beds  price  \
# 1657            -0.190090      0.401366 -0.249467  -0.439151  0.297345  125.0
# 820             -0.109668     -1.095499 -1.438810  -0.439151 -0.546858   95.0
# 2405            -0.174005      1.399275  0.939875   2.117072  0.297345  399.0
# 298             -0.174005     -0.596544 -1.438810  -0.439151 -0.546858  130.0
# 3670            -0.190090     -0.596544 -0.249467  -0.439151 -0.546858   90.0
#
#       minimum_nights  maximum_nights  number_of_reviews
# 1657       -0.065038       -0.016573          -0.482505
# 820         0.763971       -0.016573          -0.516709
# 2405       -0.065038       -0.016573          -0.482505
# 298        -0.065038       -0.016599           0.133163
# 3670       -0.341375       -0.016573          -0.482505

# %%
total_rows = normalized.shape[0]

# %%
train_data = normalized[:round(total_rows*0.75)]
test_data = normalized[round(total_rows*0.75):]

# %%
features = ["accommodates","bedrooms","bathrooms","beds"]
target = "price"

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn = KNeighborsRegressor(algorithm="brute")
knn.fit(train_data[features],train_data[target])
prediction = knn.predict(test_data[features])

# %% [markdown]
# ### When training the model, it needs to be trained on 2D data. so we are using list of lists. whereas it can predict on one-dimensional hence we only gave one vaiable as target, and did not enclose in list

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(test_data[target],prediction)
rmse = np.sqrt(mse)
rmse
# Out:
# 135.69156618190243

# %% [markdown]
# ### This is not a good model as the value of root mean square error is very high

# %% [markdown]
# ## Hyperparamater Optimization

# %%
k = [1,5,10,15,20]
rmse_values = []
for i in k:
    
    knn = KNeighborsRegressor(n_neighbors=i,algorithm="brute")
    knn.fit(train_data[features],train_data[target])
    prediction = knn.predict(test_data[features])
    mse = mean_squared_error(test_data[target],prediction)
    rmse = np.sqrt(mse)
    rmse_values.append(rmse)

# %%
rmse_values
# Out:
# [179.78456909702527,
#  135.69156618190243,
#  126.45219114305681,
#  127.54350289971384,
#  125.73197388308174]
