# %%
import pandas as pd
import numpy as np 
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
file = pd.read_csv("wh_2015.csv")

file.drop(file.index[158:])
# Out:
#                       Country                           Region  \
# 0                 Switzerland                   Western Europe
# 1                     Iceland                   Western Europe
# 2                     Denmark                   Western Europe
# 3                      Norway                   Western Europe
# 4                      Canada                    North America
# 5                     Finland                   Western Europe
# 6                 Netherlands                   Western Europe
# 7                      Sweden                   Western Europe
# 8                 New Zealand        Australia and New Zealand
# 9                   Australia        Australia and New Zealand
# 10                     Israel  Middle East and Northern Africa
# 11                 Costa Rica      Latin America and Caribbean
# 12                    Austria                   Western Europe
# 13                     Mexico      Latin America and Caribbean
# ...

# %%
x = file.iloc[0:157,8].values
x = x.reshape(-1,1)
x.shape

y = file.iloc[0:157,3].values
y = y.reshape(-1,1)
y.shape
# Out:
# (157, 1)

# %%
train_x,test_x,train_y,test_y = train_test_split(x,y,test_size=0.3,random_state=0)

# %%
train_y.shape
# Out:
# (109, 1)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(train_x,train_y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
#print(train_x.shape, train_y.shape, test_x.shape, test_y.shape)
pred = lr.predict(test_x)

# %%
pred[3]
# Out:
# array([4.39303936])

# %%
test_y[3]
test_x
# Out:
# array([[0.6598 ],
#        [0.31751],
#        [0.33207],
#        [0.22605],
#        [0.36679],
#        [0.42342],
#        [0.38282],
#        [0.59608],
#        [0.4082 ],
#        [0.09245],
#        [0.5421 ],
#        [0.19184],
#        [0.44132],
#        [0.53024],
#        [0.30033],
#        [0.36772],
#        [0.44017],
#        [0.57672],
#        [0.22917],
#        [0.55475],
#        [0.49615],
#        [0.55664],
#        [0.53122],
#        [0.63938],
#        [0.55884],
#        [0.3974 ],
#        [0.30658],
#        [0.64157],
#        [0.20107],
#        [0.     ],
#        [0.32818],
#        [0.60855],
#        [0.61583],
#        [0.46611],
#        [0.59591],
#        [0.42908],
#        [0.33457],
#        [0.40672],
#        [0.59201],
#        [0.34037],
#        [0.6404 ],
#        [0.25123],
#        [0.12102],
#        [0.62545],
#        [0.5845 ],
#        [0.41668],
#        [0.46364],
#        [0.23501]])

# %%
import matplotlib.pyplot as plt
plt.scatter(train_x,train_y,color="red")
plt.plot(train_x,lr.predict(train_x),color="blue")
plt.xlabel("Freedom")
plt.ylabel("Happiness Score")
# Out:
# Text(0, 0.5, 'Happiness Score')

# %%
plt.scatter(test_x,test_y,color="red")
plt.plot(train_x,lr.predict(train_x),color="blue")
plt.xlabel("Freedom")
plt.ylabel("Happiness Score")
# Out:
# Text(0, 0.5, 'Happiness Score')

# %%
#y = mx + c
m = lr.coef_
m
# Out:
# array([[4.7348118]])

# %%
c = lr.intercept_
c
# Out:
# array([3.32273515])

# %%
2.14758826*0.5845 + 5.98093777 #(x = 0.4082)
# Out:
# 7.23620310797

# %%
file.head(20)
# Out:
#                  Country                           Region  Happiness Rank  \
# 0            Switzerland                   Western Europe             1.0
# 1                Iceland                   Western Europe             2.0
# 2                Denmark                   Western Europe             3.0
# 3                 Norway                   Western Europe             4.0
# 4                 Canada                    North America             5.0
# 5                Finland                   Western Europe             6.0
# 6            Netherlands                   Western Europe             7.0
# 7                 Sweden                   Western Europe             8.0
# 8            New Zealand        Australia and New Zealand             9.0
# 9              Australia        Australia and New Zealand            10.0
# 10                Israel  Middle East and Northern Africa            11.0
# 11            Costa Rica      Latin America and Caribbean            12.0
# ...

# %%
test_x
# Out:
# array([[0.5845 ],
#        [0.62877],
#        [0.64157],
#        [0.63938],
#        [0.41319],
#        [0.61777]])
